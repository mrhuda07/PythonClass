# %% [markdown]
# <img src="Figures/editedLogo.png" width="400" height="200" align="center"/>
#
# <h1 align= center><font size = 5> Python Course Outline: </font></h1>
#
# <b> Programming Fundamentals: </b>
#
# 1. What is programming?
# 2. What are programming languages?
# 3. [Quiz 1: Programming and Programming Languages](https://forms.gle/9BYjfXk1PAvLqvP4A)
# 4. Writing Pseudocode
# 5. Exercise: Pseudocode example (board game or something else) - Open notepad or word doc
# 6. Designing and Debugging Programs
# 7. [Quiz 2: Programming fundamentals](https://forms.gle/Agws92dXFwTuMEbz9)
#
# <b> Python Fundamentals  </b>
#
# 1. [Review: What is Python?](https://skillcrush.com/blog/what-is-python-used-for/)
# 2. What has been built with it?
# 3. Pros and cons
# 4. Java vs Python
# 5. Course tools <br>
#       i. Jupyter Notebook<br>
#       ii. Replit <br>
#       iii. Google Forms<br>
# 6. Setting up Jupyter Notebooks
#
# <b> Data Types </b>
#
# 1. Code Comments
# 2. Data Types<br>
#     i. Built-in data types<br>
#     ii. Getting a data type<br>
#     iii. Setting data types<br>
#       - Numeric <br>
#       - String <br>
#       - Boolean<br>
#       - List <br>
#       - dict<br>
# 3. Basic Number Operations
# 4. Basic String Operations
# 8. [Quiz 3: Data Types](https://forms.gle/mZpFVodQcrq2pmAw5)
#
# <b> Variables:  </b>
#
# 1. Variables
# 2. Exercise: variables
# 3. Keywords
# 4. Literals, Expressions and Statements
# 5. [Quiz 4: Variables](https://forms.gle/WcjFrHS1xmZhFeUb7)
#
# <b> Errors:  </b>
#
# 1. We Love Errors
# 2. Syntax Errors
# 3. Reference Errors
# 4. [Quiz 5: Errors](https://forms.gle/QwrkE7R4YRsa6ULf7)
# 5. Exercise: Fix this Error!
#
# <b> Flow Control  </b>
#
# 1. Boolean Data Type
# 2. If and Else
# 4. [Quiz 6: If and Else](https://forms.gle/toTbMxHdPH83LbAA9)
# 5. Comparison Operators
# 7. [Quiz 7: Comparisons](https://forms.gle/XLGLFK7MLSHjoSig7)
# 8. “If...Else If...Else” Statements
# 10. [Quiz 8: Flow Control](https://forms.gle/daMmrzHzqceuii3u5)
#
# <b> Boolean Logic  </b>
#
# 1. Boolean Logic
# 2. [Quiz 9: Boolean logic](https://forms.gle/RLBkTD8yPV2TFZUr6)
# 3. Logical Operators
# 4. [Quiz 10: Logical Operators](https://forms.gle/cCMQ2arJvDbf3kPVA)
#
# <b> Functions  </b>
#
# 1. Functions
# 2. How To Create A Function
# 3. Return Statement
# 4. [Quiz 11: Returning Values from Functions](https://forms.gle/tbswqZ6ikEy41kvv9)
# 5. Flow Control and Logic in Functions
#     - Flow Control & Conditional
#     - Flow Control & Boolean Logic
# 6. Stock Market Feature
# 7. Bitcoin Feature
# 8. [Quiz 12: Functions](https://forms.gle/BqcWvv6NrCGqD3N48)
#
# <b> Objects </b>
#
# 1. Objects
# 2. What is A Class
# 3. Set Class
# 4. Clothing Class
# 5. [Quiz 13: Objects](https://forms.gle/LkEQLTnY5qMkdsz38)
#
# <b> End of Course </b>
#
# 1. Review
# 2. Next Steps
